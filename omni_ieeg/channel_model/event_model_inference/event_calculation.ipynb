# %%
from omni_ieeg.dataloader.datafilter import DataFilter
from omni_ieeg.utils.utils_edf import concate_edf
from tqdm import tqdm
import random
import os
import pandas as pd
random.seed(42)
dataset = "openieeg"
method = "cnn_cross_patient"
filter_list = []
dataset_folder = "/mnt/SSD1/nipsdataset/dataset/ominiieeg"
event_model_preds_folder = "/mnt/SSD1/nipsdataset/channel_training/new_event_model_preds/"
save_folder = "/mnt/SSD1/nipsdataset/channel_training/new_event_model/"
os.makedirs(save_folder, exist_ok=True)

# %%
def calculate_events(df, list_of_filters, edf_length):
    # assert there is only one unique participant
    assert len(df['participant'].unique()) == 1
    df = df[df['is_boundary'] == False]
    # Filter based on values in list_of_filters
    print(f"Before filtering: {len(df)}")
    for filter_name in list_of_filters:
        if filter_name in df.columns:
            df = df[df[filter_name] > 0.5]
        elif f"{filter_name}_pred" in df.columns:
            df = df[df[f"{filter_name}_pred"] > 0.5]
        else:
            raise ValueError(f"Filter {filter_name} not found in dataframe")
    print(f"After filtering: {len(df)}")
    
    # group by name, count how many events
    df = df.groupby('name').size().reset_index(name='count')
    df['count_per_second'] = df['count'] / edf_length
    # print(df)
    return df
    
    
    

    
    #

# %%
data_filter = DataFilter(dataset_folder)


# we want patient that has outcome, edf that is non-ictal, and has both soz and resection channels
filtered_dataset = data_filter.apply_filters(
    patient_filter=DataFilter.has_outcome_filter(),
    edf_filter=DataFilter.non_ictal_filter(),
    channel_filter=DataFilter.both_soz_and_resection_filter
)

patients = filtered_dataset.get_patients(dataset=dataset)
print(f"Found {len(patients)} patients")


for patient in patients:
    print(f"Processing {patient}")
    edf_files = filtered_dataset.get_edfs_by_patient(patient)
    patient_dfs = []
    for edf_file in edf_files:
        corresponding_channel_df = filtered_dataset.get_channels_for_edf(edf_file)
        assert corresponding_channel_df['edf_length'].unique().size == 1
        edf_length = corresponding_channel_df['edf_length'].iloc[0]
        if len(filter_list) == 0:
            base_label = "artifact"
            base_file = edf_file.replace(dataset_folder, os.path.join(event_model_preds_folder, method, base_label))
            base_file = base_file.replace(".edf", ".csv")
            assert os.path.exists(base_file), f"Preds file {base_file} does not exist"
            
            merged_df = pd.read_csv(base_file)
            event_df = calculate_events(merged_df, filter_list, edf_length)
            patient_dfs.append(event_df)
            continue
        
        # Read the first target label CSV as base
        base_label = filter_list[0]
        base_file = edf_file.replace(dataset_folder, os.path.join(event_model_preds_folder, method, base_label))
        base_file = base_file.replace(".edf", ".csv")
        assert os.path.exists(base_file), f"Preds file {base_file} does not exist"
        
        merged_df = pd.read_csv(base_file)
        
        # Find the prediction column
        pred_cols = [col for col in merged_df.columns if 'pred' in col]
        if pred_cols:
            # Rename prediction column to include target label
            merged_df = merged_df.rename(columns={pred_cols[0]: f"{base_label}_pred"})
        
        # Get non-prediction columns to verify they match in all files
        non_pred_cols = [col for col in merged_df.columns if 'pred' not in col]
        # Add other target labels' prediction columns
        for target_label in filter_list[1:]:
            current_file = edf_file.replace(dataset_folder, os.path.join(event_model_preds_folder, method, target_label))
            current_file = current_file.replace(".edf", ".csv")
            assert os.path.exists(current_file), f"Preds file {current_file} does not exist"
            
            current_df = pd.read_csv(current_file)
            
            # Assert other columns match
            current_non_pred_cols = [col for col in current_df.columns if 'pred' not in col]
            assert set(non_pred_cols) == set(current_non_pred_cols), f"Non-prediction columns don't match for {target_label}"
            
            # Check data equality in non-prediction columns
            for col in non_pred_cols:
                assert current_df[col].equals(merged_df[col]), f"Column {col} has different values in {target_label} file"
            
            # Find and add prediction column
            current_pred_cols = [col for col in current_df.columns if 'pred' in col]
            if current_pred_cols:
                merged_df[f"{target_label}_pred"] = current_df[current_pred_cols[0]]
        event_df = calculate_events(merged_df, filter_list, edf_length)
        patient_dfs.append(event_df)
    
     # Concatenate all dataframes
    patient_all_events = pd.concat(patient_dfs, ignore_index=True)
    # Group by name and calculate means
    averaged_events = patient_all_events.groupby('name').agg({
        'count': 'mean',
        'count_per_second': 'mean'
    }).reset_index()
    
    channel_df = filtered_dataset.get_merged_channels_for_patient(patient)
    merged_paitnet_df = pd.merge(averaged_events, channel_df, on='name', how='inner')
    os.makedirs(os.path.join(save_folder, method, f"filter_{filter_list}"), exist_ok=True)
    merged_paitnet_df.to_csv(os.path.join(save_folder, method, f"filter_{filter_list}", f"{patient}.csv"), index=False)
# Out:
# Found 162 patients
# Processing sub-openieegDetroit001
# Before filtering: 2642
# After filtering: 2642
# Processing sub-openieegDetroit002
# Before filtering: 4139
# After filtering: 4139
# Processing sub-openieegDetroit003
# Before filtering: 2631
# After filtering: 2631
# Processing sub-openieegDetroit004
# Before filtering: 727
# After filtering: 727
# Processing sub-openieegDetroit005
# Before filtering: 4308
# After filtering: 4308
# Processing sub-openieegDetroit006
# Before filtering: 816
# After filtering: 816
# Processing sub-openieegDetroit007
# Before filtering: 2030
# After filtering: 2030
# Processing sub-openieegDetroit008
# Before filtering: 1416
# After filtering: 1416
# Processing sub-openieegDetroit009
# Before filtering: 1080
# After filtering: 1080
# Processing sub-openieegDetroit010
# Before filtering: 5751
# After filtering: 5751
# Processing sub-openieegDetroit011
# Before filtering: 361
# After filtering: 361
# Processing sub-openieegDetroit012
# Before filtering: 2868
# After filtering: 2868
# Processing sub-openieegDetroit013
# Before filtering: 1919
# After filtering: 1919
# Processing sub-openieegDetroit014
# Before filtering: 1380
# After filtering: 1380
# Processing sub-openieegDetroit015
# Before filtering: 1806
# After filtering: 1806
# Processing sub-openieegDetroit016
# Before filtering: 2645
# After filtering: 2645
# Processing sub-openieegDetroit017
# Before filtering: 8617
# After filtering: 8617
# Processing sub-openieegDetroit018
# Before filtering: 1418
# After filtering: 1418
# Processing sub-openieegDetroit019
# Before filtering: 1335
# After filtering: 1335
# Processing sub-openieegDetroit020
# Before filtering: 11493
# After filtering: 11493
# Processing sub-openieegDetroit021
# Before filtering: 3361
# After filtering: 3361
# Processing sub-openieegDetroit022
# Before filtering: 1011
# After filtering: 1011
# Processing sub-openieegDetroit023
# Before filtering: 1174
# After filtering: 1174
# Processing sub-openieegDetroit024
# Before filtering: 2187
# After filtering: 2187
# Processing sub-openieegDetroit025
# Before filtering: 2228
# After filtering: 2228
# Processing sub-openieegDetroit026
# Before filtering: 484
# After filtering: 484
# Processing sub-openieegDetroit027
# Before filtering: 141
# After filtering: 141
# Processing sub-openieegDetroit028
# Before filtering: 1068
# After filtering: 1068
# Processing sub-openieegDetroit029
# Before filtering: 920
# After filtering: 920
# Processing sub-openieegDetroit030
# Before filtering: 1460
# After filtering: 1460
# Processing sub-openieegDetroit031
# Before filtering: 4640
# After filtering: 4640
# Processing sub-openieegDetroit032
# Before filtering: 812
# After filtering: 812
# Processing sub-openieegDetroit033
# Before filtering: 1050
# After filtering: 1050
# Processing sub-openieegDetroit034
# Before filtering: 1205
# After filtering: 1205
# Processing sub-openieegDetroit035
# Before filtering: 516
# After filtering: 516
# Processing sub-openieegDetroit036
# Before filtering: 1475
# After filtering: 1475
# Processing sub-openieegDetroit037
# Before filtering: 615
# After filtering: 615
# Processing sub-openieegDetroit038
# Before filtering: 2857
# After filtering: 2857
# Processing sub-openieegDetroit039
# Before filtering: 1089
# After filtering: 1089
# Processing sub-openieegDetroit040
# Before filtering: 445
# After filtering: 445
# Processing sub-openieegDetroit041
# Before filtering: 826
# After filtering: 826
# Processing sub-openieegDetroit042
# Before filtering: 1312
# After filtering: 1312
# Processing sub-openieegDetroit043
# Before filtering: 3533
# After filtering: 3533
# Processing sub-openieegDetroit044
# Before filtering: 568
# After filtering: 568
# Processing sub-openieegDetroit045
# Before filtering: 1682
# After filtering: 1682
# Processing sub-openieegDetroit046
# Before filtering: 4417
# After filtering: 4417
# Processing sub-openieegDetroit047
# Before filtering: 811
# After filtering: 811
# Processing sub-openieegDetroit048
# Before filtering: 401
# After filtering: 401
# Processing sub-openieegDetroit049
# Before filtering: 433
# After filtering: 433
# Processing sub-openieegDetroit050
# Before filtering: 3818
# After filtering: 3818
# Processing sub-openieegDetroit051
# Before filtering: 1893
# After filtering: 1893
# Processing sub-openieegDetroit052
# Before filtering: 1299
# After filtering: 1299
# Processing sub-openieegDetroit053
# Before filtering: 2735
# After filtering: 2735
# Processing sub-openieegDetroit054
# Before filtering: 1355
# After filtering: 1355
# Processing sub-openieegDetroit055
# Before filtering: 420
# After filtering: 420
# Processing sub-openieegDetroit056
# Before filtering: 1217
# After filtering: 1217
# Processing sub-openieegDetroit057
# Before filtering: 1168
# After filtering: 1168
# Processing sub-openieegDetroit058
# Before filtering: 7817
# After filtering: 7817
# Processing sub-openieegDetroit059
# Before filtering: 3305
# After filtering: 3305
# Processing sub-openieegDetroit060
# Before filtering: 3744
# After filtering: 3744
# Processing sub-openieegDetroit061
# Before filtering: 680
# After filtering: 680
# Processing sub-openieegDetroit062
# Before filtering: 1139
# After filtering: 1139
# Processing sub-openieegDetroit063
# Before filtering: 597
# After filtering: 597
# Processing sub-openieegDetroit064
# Before filtering: 1192
# After filtering: 1192
# Processing sub-openieegDetroit065
# Before filtering: 920
# After filtering: 920
# Processing sub-openieegDetroit066
# Before filtering: 8582
# After filtering: 8582
# Processing sub-openieegDetroit067
# Before filtering: 1321
# After filtering: 1321
# Processing sub-openieegDetroit068
# Before filtering: 861
# After filtering: 861
# Processing sub-openieegDetroit069
# Before filtering: 320
# After filtering: 320
# Processing sub-openieegDetroit070
# Before filtering: 1560
# After filtering: 1560
# Processing sub-openieegDetroit071
# Before filtering: 4009
# After filtering: 4009
# Processing sub-openieegDetroit072
# Before filtering: 3111
# After filtering: 3111
# Processing sub-openieegDetroit073
# Before filtering: 419
# After filtering: 419
# Processing sub-openieegDetroit074
# Before filtering: 837
# After filtering: 837
# Processing sub-openieegDetroit075
# Before filtering: 6
# After filtering: 6
# Processing sub-openieegDetroit076
# Before filtering: 1153
# After filtering: 1153
# Processing sub-openieegDetroit077
# Before filtering: 907
# After filtering: 907
# Processing sub-openieegDetroit078
# Before filtering: 432
# After filtering: 432
# Processing sub-openieegDetroit079
# Before filtering: 659
# After filtering: 659
# Processing sub-openieegDetroit080
# Before filtering: 2933
# After filtering: 2933
# Processing sub-openieegDetroit081
# Before filtering: 1548
# After filtering: 1548
# Processing sub-openieegDetroit082
# Before filtering: 1088
# After filtering: 1088
# Processing sub-openieegDetroit083
# Before filtering: 3171
# After filtering: 3171
# Processing sub-openieegDetroit084
# Before filtering: 1196
# After filtering: 1196
# Processing sub-openieegDetroit085
# Before filtering: 1619
# After filtering: 1619
# Processing sub-openieegDetroit086
# Before filtering: 381
# After filtering: 381
# Processing sub-openieegDetroit087
# Before filtering: 779
# After filtering: 779
# Processing sub-openieegDetroit088
# Before filtering: 1751
# After filtering: 1751
# Processing sub-openieegDetroit089
# Before filtering: 785
# After filtering: 785
# Processing sub-openieegDetroit090
# Before filtering: 738
# After filtering: 738
# Processing sub-openieegDetroit091
# Before filtering: 879
# After filtering: 879
# Processing sub-openieegDetroit092
# Before filtering: 1024
# After filtering: 1024
# Processing sub-openieegDetroit093
# Before filtering: 362
# After filtering: 362
# Processing sub-openieegDetroit094
# Before filtering: 4009
# After filtering: 4009
# Processing sub-openieegDetroit095
# Before filtering: 350
# After filtering: 350
# Processing sub-openieegUCLA01
# Before filtering: 6360
# After filtering: 6360
# Processing sub-openieegUCLA02
# Before filtering: 7972
# After filtering: 7972
# Processing sub-openieegUCLA03
# Before filtering: 29814
# After filtering: 29814
# Processing sub-openieegUCLA04
# Before filtering: 25564
# After filtering: 25564
# Processing sub-openieegUCLA05
# Before filtering: 10509
# After filtering: 10509
# Processing sub-openieegUCLA06
# Before filtering: 15223
# After filtering: 15223
# Processing sub-openieegUCLA07
# Before filtering: 41974
# After filtering: 41974
# Processing sub-openieegUCLA09
# Before filtering: 7740
# After filtering: 7740
# Processing sub-openieegUCLA10
# Before filtering: 123420
# After filtering: 123420
# Processing sub-openieegUCLA11
# Before filtering: 28033
# After filtering: 28033
# Processing sub-openieegUCLA12
# Before filtering: 11488
# After filtering: 11488
# Processing sub-openieegUCLA13
# Before filtering: 12281
# After filtering: 12281
# Processing sub-openieegUCLA14
# Before filtering: 13982
# After filtering: 13982
# Processing sub-openieegUCLA16
# Before filtering: 22543
# After filtering: 22543
# Processing sub-openieegUCLA17
# Before filtering: 69038
# After filtering: 69038
# Processing sub-openieegUCLA19
# Before filtering: 17969
# After filtering: 17969
# Processing sub-openieegUCLA22
# Before filtering: 214414
# After filtering: 214414
# Processing sub-openieegUCLA25
# Before filtering: 44125
# After filtering: 44125
# Processing sub-openieegUCLA26
# Before filtering: 43958
# After filtering: 43958
# Processing sub-openieegUCLA27
# Before filtering: 56444
# After filtering: 56444
# Processing sub-openieegUCLA30
# Before filtering: 21261
# After filtering: 21261
# Processing sub-openieegUCLA31
# Before filtering: 18726
# After filtering: 18726
# Processing sub-openieegUCLA33
# Before filtering: 12484
# After filtering: 12484
# Processing sub-openieegUCLA34
# Before filtering: 48059
# After filtering: 48059
# Processing sub-openieegUCLA38
# Before filtering: 31137
# After filtering: 31137
# Processing sub-openieegUCLA41
# Before filtering: 25053
# After filtering: 25053
# Processing sub-openieegUCLA50
# Before filtering: 18568
# After filtering: 18568
# Processing sub-openieegDetroit096
# Before filtering: 822
# After filtering: 822
# Processing sub-openieegDetroit097
# Before filtering: 3815
# After filtering: 3815
# Processing sub-openieegDetroit098
# Before filtering: 1367
# After filtering: 1367
# Processing sub-openieegDetroit099
# Before filtering: 311
# After filtering: 311
# Processing sub-openieegDetroit100
# Before filtering: 434
# After filtering: 434
# Processing sub-openieegDetroit101
# Before filtering: 3754
# After filtering: 3754
# Processing sub-openieegDetroit102
# Before filtering: 406
# After filtering: 406
# Processing sub-openieegDetroit103
# Before filtering: 555
# After filtering: 555
# Processing sub-openieegDetroit104
# Before filtering: 412
# After filtering: 412
# Processing sub-openieegDetroit105
# Before filtering: 8350
# After filtering: 8350
# Processing sub-openieegDetroit106
# Before filtering: 1344
# After filtering: 1344
# Processing sub-openieegDetroit107
# Before filtering: 8796
# After filtering: 8796
# Processing sub-openieegDetroit108
# Before filtering: 641
# After filtering: 641
# Processing sub-openieegDetroit109
# Before filtering: 611
# After filtering: 611
# Processing sub-openieegDetroit110
# Before filtering: 359
# After filtering: 359
# Processing sub-openieegDetroit111
# Before filtering: 355
# After filtering: 355
# Processing sub-openieegDetroit112
# Before filtering: 4133
# After filtering: 4133
# Processing sub-openieegDetroit113
# Before filtering: 709
# After filtering: 709
# Processing sub-openieegDetroit114
# Before filtering: 5770
# After filtering: 5770
# Processing sub-openieegDetroit115
# Before filtering: 2259
# After filtering: 2259
# Processing sub-openieegDetroit116
# Before filtering: 753
# After filtering: 753
# Processing sub-openieegDetroit117
# Before filtering: 953
# After filtering: 953
# Processing sub-openieegDetroit118
# Before filtering: 1390
# After filtering: 1390
# Processing sub-openieegDetroit119
# Before filtering: 960
# After filtering: 960
# Processing sub-openieegDetroit120
# Before filtering: 6372
# After filtering: 6372
# Processing sub-openieegDetroit121
# Before filtering: 432
# After filtering: 432
# Processing sub-openieegDetroit122
# Before filtering: 3459
# After filtering: 3459
# Processing sub-openieegDetroit123
# Before filtering: 1844
# After filtering: 1844
# Processing sub-openieegDetroit124
# Before filtering: 244
# After filtering: 244
# Processing sub-openieegDetroit125
# Before filtering: 382
# After filtering: 382
# Processing sub-openieegDetroit126
# Before filtering: 1180
# After filtering: 1180
# Processing sub-openieegDetroit127
# Before filtering: 4647
# After filtering: 4647
# Processing sub-openieegDetroit128
# Before filtering: 3819
# After filtering: 3819
# Processing sub-openieegDetroit129
# Before filtering: 5984
# After filtering: 5984
# Processing sub-openieegDetroit130
# Before filtering: 965
# After filtering: 965
# Processing sub-openieegDetroit131
# Before filtering: 1913
# After filtering: 1913
# Processing sub-openieegDetroit132
# Before filtering: 1444
# After filtering: 1444
# Processing sub-openieegDetroit133
# Before filtering: 1874
# After filtering: 1874
# Processing sub-openieegDetroit134
# Before filtering: 1531
# After filtering: 1531
# Processing sub-openieegDetroit135
# Before filtering: 2473
# After filtering: 2473
